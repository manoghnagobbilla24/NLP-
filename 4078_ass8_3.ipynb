# %% [markdown]
# <a href="https://colab.research.google.com/github/manoghnagobbilla24/NLP-/blob/main/4078_ass8_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
D1 = "Artificial intelligence is one of the fastest growing fields in computer science."
D2 = "It focuses on building intelligent systems that can perform tasks requiring human intelligence."
D3 = "These tasks include speech recognition, language translation, image classification, and decision making."
D4 = "Machine learning is a core part of artificial intelligence because it allows systems to learn from data."

# %%
import collections

# Combine the text from D1, D2, D3, D4
combined_text = f"{D1} {D2} {D3} {D4}"

# Tokenize the combined text into words and convert to lowercase
words = combined_text.lower().split()

# Calculate unigram counts
unigram_counts = collections.Counter(words)

# Print the unigram counts
print("Unigram Counts:")
for word, count in unigram_counts.most_common():
    print(f"{word}: {count}")
#Vocabulary size is length of unigrams
V=len(unigram_counts)
print("Vocabulary Size=",V)
# Out:
# Unigram Counts:
# artificial: 2
# intelligence: 2
# is: 2
# of: 2
# it: 2
# systems: 2
# tasks: 2
# one: 1
# the: 1
# fastest: 1
# growing: 1
# fields: 1
# in: 1
# computer: 1
# science.: 1
# focuses: 1
# on: 1
# building: 1
# intelligent: 1
# that: 1
# can: 1
# perform: 1
# requiring: 1
# human: 1
# intelligence.: 1
# these: 1
# include: 1
# speech: 1
# recognition,: 1
# language: 1
# translation,: 1
# image: 1
# classification,: 1
# and: 1
# decision: 1
# making.: 1
# machine: 1
# learning: 1
# a: 1
# core: 1
# part: 1
# because: 1
# allows: 1
# to: 1
# learn: 1
# from: 1
# data.: 1
# Vocabulary Size= 47

# %%
import collections


combined_text = f"{D1} {D2} {D3} {D4}"
words = combined_text.lower().split()

# Generate bigrams
bigrams = []
for i in range(len(words) - 1):
    bigrams.append((words[i], words[i+1]))

# Calculate bigram counts
bigram_counts = collections.Counter(bigrams)

# Print the bigram counts
print("\nBigram Counts:")
for bigram, count in bigram_counts.most_common():
    print(f"{bigram[0]} {bigram[1]}: {count}")
# Out:
# Bigram Counts:
# artificial intelligence: 2
# intelligence is: 1
# is one: 1
# one of: 1
# of the: 1
# the fastest: 1
# fastest growing: 1
# growing fields: 1
# fields in: 1
# in computer: 1
# computer science.: 1
# science. it: 1
# it focuses: 1
# focuses on: 1
# on building: 1
# building intelligent: 1
# intelligent systems: 1
# systems that: 1
# that can: 1
# can perform: 1
# perform tasks: 1
# tasks requiring: 1
# requiring human: 1
# human intelligence.: 1
# intelligence. these: 1
# these tasks: 1
# tasks include: 1
# include speech: 1
# speech recognition,: 1
# recognition, language: 1
# language translation,: 1
# translation, image: 1
# image classification,: 1
# classification, and: 1
# and decision: 1
# decision making.: 1
# making. machine: 1
# machine learning: 1
# learning is: 1
# is a: 1
# a core: 1
# core part: 1
# part of: 1
# of artificial: 1
# intelligence because: 1
# because it: 1
# it allows: 1
# allows systems: 1
# systems to: 1
# to learn: 1
# learn from: 1
# from data.: 1

# %%
import collections
combined_text = f"{D1} {D2} {D3} {D4}"
words = combined_text.lower().split()

# Generate bigrams
Trigrams = []
for i in range(len(words) - 2):
    Trigrams.append((words[i], words[i+1], words[i+2]))

# Calculate bigram counts
Trigrams_counts = collections.Counter(Trigrams)

# Print the bigram counts
print("\nTrigrams Counts:")
for Trigrams, count in Trigrams_counts.most_common():
    print(f"{Trigrams[0]} {Trigrams[1]} {Trigrams[2]}: {count}")
# Out:
# Trigrams Counts:
# artificial intelligence is: 1
# intelligence is one: 1
# is one of: 1
# one of the: 1
# of the fastest: 1
# the fastest growing: 1
# fastest growing fields: 1
# growing fields in: 1
# fields in computer: 1
# in computer science.: 1
# computer science. it: 1
# science. it focuses: 1
# it focuses on: 1
# focuses on building: 1
# on building intelligent: 1
# building intelligent systems: 1
# intelligent systems that: 1
# systems that can: 1
# that can perform: 1
# can perform tasks: 1
# perform tasks requiring: 1
# tasks requiring human: 1
# requiring human intelligence.: 1
# human intelligence. these: 1
# intelligence. these tasks: 1
# these tasks include: 1
# tasks include speech: 1
# include speech recognition,: 1
# speech recognition, language: 1
# recognition, language translation,: 1
# language translation, image: 1
# translation, image classification,: 1
# image classification, and: 1
# classification, and decision: 1
# and decision making.: 1
# decision making. machine: 1
# making. machine learning: 1
# machine learning is: 1
# learning is a: 1
# is a core: 1
# a core part: 1
# core part of: 1
# part of artificial: 1
# of artificial intelligence: 1
# artificial intelligence because: 1
# intelligence because it: 1
# because it allows: 1
# it allows systems: 1
# allows systems to: 1
# systems to learn: 1
# to learn from: 1
# learn from data.: 1

# %%
def predict_next_word_bigram(word_sequence, bigram_counts, unigram_counts):
    # Tokenize the input sequence and get the last word
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."
    last_word = words_in_sequence[-1]

    # Find potential next words based on bigrams starting with last_word
    potential_next_words = {}
    for (w1, w2), count in bigram_counts.items():
        if w1 == last_word:
            potential_next_words[w2] = count

    if not potential_next_words:
        return f"No bigram found starting with '{last_word}'."

    # Calculate probabilities for potential next words
    # P(w2 | w1) = Count(w1, w2) / Count(w1)
    last_word_unigram_count = unigram_counts.get(last_word, 0)
    if last_word_unigram_count == 0:
        return f"'{last_word}' not found in unigram counts. Cannot predict next word."
        predicted_word = None
    max_probability = -1

    for next_word, bigram_count in potential_next_words.items():
        probability = bigram_count / last_word_unigram_count
        print("probability of  " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word
    # Example usage:
# Ensure bigram_counts and unigram_counts are defined from previous cells
# (They are present in the kernel state.)

# Try with a word sequence
sequence1 = "Artificial"
print("Next word:", predict_next_word_bigram(sequence1, bigram_counts, unigram_counts))

sequence2 = "machine learning"
print("Next word:", predict_next_word_bigram(sequence2, bigram_counts, unigram_counts))

sequence3 = "data"
print("Next word:", predict_next_word_bigram(sequence3, bigram_counts, unigram_counts))

sequence4 = "unknown word"
print("Next word:", predict_next_word_bigram(sequence4, bigram_counts, unigram_counts))
# Out:
# probability of  intelligence is  1.0
# Next word: intelligence
# probability of  is is  1.0
# Next word: is
# Next word: No bigram found starting with 'data'.
# Next word: No bigram found starting with 'word'.

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_bigram(ip_text, bigram_counts, unigram_counts)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textIt
# probability of  focuses is  0.5
# probability of  allows is  0.5
# Given sequence: 'It ', predicted next word: 'focuses'

# %%
def predict_next_word_trigram(word_sequence, Trigrams_counts, bigram_counts):
    # Tokenize the input sequence
    words_in_sequence = word_sequence.lower().split()
    if not words_in_sequence:
        return "Please provide a word sequence."

    # Ensure at least two words for trigram prediction
    if len(words_in_sequence) < 2:
        return "Sequence must contain at least two words for trigram prediction."

    # Get the last two words as a tuple
    last_two_words_tuple = tuple(words_in_sequence[-2:])

    # Find potential next words based on trigrams starting with the last two words
    potential_next_words = {}
    for (w1, w2, w3), count in Trigrams_counts.items():
        if (w1, w2) == last_two_words_tuple:
            potential_next_words[w3] = count

    if not potential_next_words:
        return f"No trigram found starting with '{' '.join(last_two_words_tuple)}'."
        # Calculate probabilities for potential next words
    # P(w3 | w1,w2) = Count(w1, w2, w3) / Count(w1, w2)
    # The denominator should be the count of the bigram (w1, w2)
    last_two_words_bigram_count = bigram_counts.get(last_two_words_tuple, 0)
    if last_two_words_bigram_count == 0:
        return f"'{' '.join(last_two_words_tuple)}' not found as a bigram. Cannot predict next word."

    predicted_word = None
    max_probability = -1

    for next_word, trigram_count in potential_next_words.items():
        probability = trigram_count / last_two_words_bigram_count
        print("probability of  " f'{next_word}' " is ", probability)
        if probability > max_probability:
            max_probability = probability
            predicted_word = next_word

    return predicted_word
sequence1 = "Artificial intelligence "
next_word1 = predict_next_word_trigram(sequence1, Trigrams_counts, bigram_counts)
print(f"Given sequence: '{sequence1}', predicted next word: '{next_word1}'")

sequence2 = "machine learning"
next_word2 = predict_next_word_trigram(sequence2, Trigrams_counts, bigram_counts)
print(f"Given sequence: '{sequence2}', predicted next word: '{next_word2}'")
# Out:
# probability of  is is  0.5
# probability of  because is  0.5
# Given sequence: 'Artificial intelligence ', predicted next word: 'is'
# probability of  is is  1.0
# Given sequence: 'machine learning', predicted next word: 'is'

# %%
ip_text=input("enter text")
next_word1 = predict_next_word_trigram(ip_text, Trigrams_counts, bigram_counts)
print(f"Given sequence: '{ip_text}', predicted next word: '{next_word1}'")
# Out:
# enter textIt focuses
# probability of  on is  1.0
# Given sequence: 'It focuses', predicted next word: 'on'
